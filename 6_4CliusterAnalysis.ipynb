# %% [markdown]
# <a href="https://colab.research.google.com/github/ashugk/365datadcience/blob/main/6_4CliusterAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv('Country_clusters.csv')
data.head(5)
# Out:
#    Country  Latitude  Longitude Language
# 0      USA     44.97    -103.77  English
# 1   Canada     62.40     -96.80  English
# 2   France     46.75       2.40   French
# 3       UK     54.01      -2.53  English
# 4  Germany     51.15      10.40   German

# %% [markdown]
# Map the data

# %%
data_mapped=data.copy()
data_mapped['Language']= data_mapped['Language'].map({'English':0, 'French':1, 'German':2})
data_mapped
# Out:
#      Country  Latitude  Longitude  Language
# 0        USA     44.97    -103.77         0
# 1     Canada     62.40     -96.80         0
# 2     France     46.75       2.40         1
# 3         UK     54.01      -2.53         0
# 4    Germany     51.15      10.40         2
# 5  Australia    -25.45     133.11         0

# %% [markdown]
# Selecting the feature

# %%
x= data_mapped.iloc[:,1:4]
x
# Out:
#    Latitude  Longitude  Language
# 0     44.97    -103.77         0
# 1     62.40     -96.80         0
# 2     46.75       2.40         1
# 3     54.01      -2.53         0
# 4     51.15      10.40         2
# 5    -25.45     133.11         0

# %% [markdown]
# Clustering

# %%
kmeans= KMeans(3)
kmeans.fit(x)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
kmeans.get_params()
# Out:
# {'algorithm': 'lloyd',
#  'copy_x': True,
#  'init': 'k-means++',
#  'max_iter': 300,
#  'n_clusters': 3,
#  'n_init': 'warn',
#  'random_state': None,
#  'tol': 0.0001,
#  'verbose': 0}

# %% [markdown]
# Clustering result

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([0, 0, 1, 1, 1, 2], dtype=int32)

# %%
data_with_cluster = data_mapped.copy()
data_with_cluster['Cluster']= identified_clusters
data_with_cluster
# Out:
#      Country  Latitude  Longitude  Language  Cluster
# 0        USA     44.97    -103.77         0        0
# 1     Canada     62.40     -96.80         0        0
# 2     France     46.75       2.40         1        1
# 3         UK     54.01      -2.53         0        1
# 4    Germany     51.15      10.40         2        1
# 5  Australia    -25.45     133.11         0        2

# %%
plt.scatter(data_with_cluster['Longitude'],data_with_cluster['Latitude'],c=data_with_cluster['Cluster'], cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.show()

# %% [markdown]
# Selecting with no of clusters

# %% [markdown]
# WCSS(within-cluster sum of squares)

# %%
kmeans.inertia_
# Out:
# 290.10523333333333

# %%
wcss=[]

for i in range(1,7):
  kmeans= KMeans(i)
  kmeans.fit(x)
  wcss_iter = kmeans.inertia_
  wcss.append(wcss_iter)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
wcss
# Out:
# [42605.41356666667,
#  13208.958119999996,
#  290.10523333333333,
#  113.91233333333332,
#  39.00624999999998,
#  0.0]

# %%
number_clusters = range(1,7)
plt.plot(number_clusters, wcss)
plt.title('The Elbow method')
plt.xlabel('The number of cluster')
plt.ylabel('within-cluster sum of squares')
# Out:
# Text(0, 0.5, 'within-cluster sum of squares')
